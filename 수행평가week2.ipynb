# %%
x=int(input("부모님으로 부터 받은 용돈:"))
y = x-3550 
print("거스름돈 :",y,"원")
a = y%500
z = y // 500
print(f"500원 짜리 거스름돈 : {z}개")
b = a//100
c = a%100
print(f"100원 짜리 거스름돈 : {b}개")
d = c // 50
print(f"50원짜리 거스름돈 : {d}개")
# Out:
# 부모님으로 부터 받은 용돈:10000
# 거스름돈 : 6450 원
# 500원 짜리 거스름돈 : 12개
# 100원 짜리 거스름돈 : 4개
# 50원짜리 거스름돈 : 1개

# %%
x = input("알파벳을 입력하세요 : ")
a = x.isupper()
y = "대문자 입니다." if a == True else "소문자 입니다."
print(f"당신이 입력한 문자 {x}는",y)
# Out:
# 알파벳을 입력하세요 : B
# 당신이 입력한 문자 B는 대문자 입니다.
